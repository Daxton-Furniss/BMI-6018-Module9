# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
flights_data = pd.read_csv('flights.csv')
flights_data.head(10)
weather_data_pd = pd.read_csv('weather.csv')
weather_data_np = weather_data_pd.to_numpy()

# %%
flights_data
# Out:
#         Unnamed: 0  year  month  day  dep_time  dep_delay  arr_time  \
# 0                1  2013      1    1     517.0        2.0     830.0
# 1                2  2013      1    1     533.0        4.0     850.0
# 2                3  2013      1    1     542.0        2.0     923.0
# 3                4  2013      1    1     544.0       -1.0    1004.0
# 4                5  2013      1    1     554.0       -6.0     812.0
# ...            ...   ...    ...  ...       ...        ...       ...
# 336771      336772  2013      9   30       NaN        NaN       NaN
# 336772      336773  2013      9   30       NaN        NaN       NaN
# 336773      336774  2013      9   30       NaN        NaN       NaN
# 336774      336775  2013      9   30       NaN        NaN       NaN
# 336775      336776  2013      9   30       NaN        NaN       NaN
#
#         arr_delay carrier tailnum  flight origin dest  air_time  distance  \
# 0            11.0      UA  N14228    1545    EWR  IAH     227.0      1400
# ...

# %%
weather_data_pd
# Out:
#       Unnamed: 0 origin  year  month   day  hour   temp   dewp  humid  \
# 0              1    EWR  2013    1.0   1.0   0.0  37.04  21.92  53.97
# 1              2    EWR  2013    1.0   1.0   1.0  37.04  21.92  53.97
# 2              3    EWR  2013    1.0   1.0   2.0  37.94  21.92  52.09
# 3              4    EWR  2013    1.0   1.0   3.0  37.94  23.00  54.51
# 4              5    EWR  2013    1.0   1.0   4.0  37.94  24.08  57.04
# ...          ...    ...   ...    ...   ...   ...    ...    ...    ...
# 8714        8715    JFK  2013    9.0   2.0  20.0  75.20  73.40  94.14
# 8715        8716    JFK  2013   10.0  23.0  10.0  48.92  39.02  68.51
# 8716        8717    JFK  2013   10.0  23.0  11.0  48.92  39.02  68.51
# 8717        8718    JFK  2013   12.0  17.0   5.0  26.96  10.94  50.34
# 8718        8719    LGA  2013    8.0  22.0  22.0  75.92  66.92  73.68
#
#       wind_dir  wind_speed  wind_gust  precip  pressure  visib
# 0        230.0    10.35702  11.918651     0.0    1013.9   10.0
# ...

# %%
#Question 1 
JFK_to_SLC = len(flights_data[(flights_data['origin'] == 'JFK') & (flights_data['dest'] == 'SLC')])
print("Number of flights from JFK to SLC:", JFK_to_SLC)
# Out:
# Number of flights from JFK to SLC: 2113

# %%
#Question 2
Airlines_to_SLC = flights_data[flights_data['dest'] == 'SLC']['carrier'].nunique()
print("Number of Airlines to SLC':", Airlines_to_SLC)
# Out:
# Number of Airlines to SLC': 2

# %%
#Question 3
average_delay = flights_data[flights_data['dest'] == 'RDU']['arr_delay'].mean()
print("Average arrival delay for flights to RDU:", average_delay.round(2))
# Out:
# Average arrival delay for flights to RDU: 10.05

# %%
#Question 4
sea_flights = flights_data[flights_data['dest'] == 'SEA']
total_sea_flights = len(sea_flights)
nyc_flights = sea_flights[(sea_flights['origin'] == 'LGA') | (sea_flights['origin'] == 'JFK')]
flights_from_lga_jfk = len(nyc_flights)
proportion = flights_from_lga_jfk / total_sea_flights
print(f"Proportion of flights from LGA and JFK to SEA: {proportion:.2%}")
# Out:
# Proportion of flights from LGA and JFK to SEA: 53.33%

# %%
#Question 5
average_delay_per_date = flights_data.groupby('day')['dep_delay'].mean().reset_index()
date_and_largest_delay = average_delay_per_date[average_delay_per_date['dep_delay'] == average_delay_per_date['dep_delay'].max()]
date_and_largest_delay
# Out:
#    day  dep_delay
# 7    8  21.760773

# %%
#Question 6
average_arrival_per_date = flights_data.groupby('day')['arr_delay'].mean().reset_index()
date_and_largest_arrival = average_arrival_per_date[average_arrival_per_date['arr_delay'] == average_arrival_per_date['arr_delay'].max()]
date_and_largest_arrival
# Out:
#    day  arr_delay
# 7    8  19.072177

# %%
#Question 7
flights_data['speed'] = flights_data['distance'] / flights_data['air_time']
lga_jfk_flights = flights_data[flights_data['origin'].isin(['LGA', 'JFK'])]
fastest_flight = lga_jfk_flights.loc[lga_jfk_flights['speed'].idxmax()]
x = fastest_flight[['tailnum', 'speed']]
x
# Out:
# tailnum       N666DN
# speed      11.723077
# Name: 216447, dtype: object

# %%
#Question 8
weather_data_pd.fillna(0, inplace=True)
weather_data_pd
# Out:
#       Unnamed: 0 origin  year  month   day  hour   temp   dewp  humid  \
# 0              1    EWR  2013    1.0   1.0   0.0  37.04  21.92  53.97
# 1              2    EWR  2013    1.0   1.0   1.0  37.04  21.92  53.97
# 2              3    EWR  2013    1.0   1.0   2.0  37.94  21.92  52.09
# 3              4    EWR  2013    1.0   1.0   3.0  37.94  23.00  54.51
# 4              5    EWR  2013    1.0   1.0   4.0  37.94  24.08  57.04
# ...          ...    ...   ...    ...   ...   ...    ...    ...    ...
# 8714        8715    JFK  2013    9.0   2.0  20.0  75.20  73.40  94.14
# 8715        8716    JFK  2013   10.0  23.0  10.0  48.92  39.02  68.51
# 8716        8717    JFK  2013   10.0  23.0  11.0  48.92  39.02  68.51
# 8717        8718    JFK  2013   12.0  17.0   5.0  26.96  10.94  50.34
# 8718        8719    LGA  2013    8.0  22.0  22.0  75.92  66.92  73.68
#
#       wind_dir  wind_speed  wind_gust  precip  pressure  visib
# 0        230.0    10.35702  11.918651     0.0    1013.9   10.0
# ...

# %%
#Question 9
feb_observations = weather_data_pd['month'].value_counts().get(2.0, 0)
print(feb_observations)
# Out:
# 671

# %%
#Question 10
feb_mean = weather_data_pd[weather_data_pd["month"] == 2.0]["humid"].mean()
print(feb_mean)
# Out:
# 62.91815201192251

# %%
#Question 11
feb_humid = weather_data_pd[weather_data_pd["month"] == 2.0]["humid"]
feb_std = feb_humid.std()
print(feb_std)
# Out:
# 20.352072009682594
